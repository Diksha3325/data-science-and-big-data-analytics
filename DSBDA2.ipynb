# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('StudentPerformance.csv')
df
# Out:
#     marths score  reading score  writing score  placement score  \
# 0           61.0             83             80             75.0
# 1           60.0             86             61             79.0
# 2           63.0             94             69             79.0
# 3           74.0             32             80             87.0
# 4           80.0             91             64             90.0
# 5           75.0             92             60             97.0
# 6           79.0             89             67             76.0
# 7           72.0             89             65             94.0
# 8           75.0             78             79             84.0
# 9            NaN             85             72             82.0
# 10          69.0             76             68             77.0
# 11          76.0             89             67             75.0
# 12          68.0             81             76             75.0
# 13          63.0             76             97             93.0
# ...

# %%
df.notnull()
# Out:
#     marths score  reading score  writing score  placement score  \
# 0           True           True           True             True
# 1           True           True           True             True
# 2           True           True           True             True
# 3           True           True           True             True
# 4           True           True           True             True
# 5           True           True           True             True
# 6           True           True           True             True
# 7           True           True           True             True
# 8           True           True           True             True
# 9          False           True           True             True
# 10          True           True           True             True
# 11          True           True           True             True
# 12          True           True           True             True
# 13          True           True           True             True
# ...

# %%
seriesl = pd.notnull(df["marths score"])
df[seriesl]
# Out:
#     marths score  reading score  writing score  placement score  \
# 0           61.0             83             80             75.0
# 1           60.0             86             61             79.0
# 2           63.0             94             69             79.0
# 3           74.0             32             80             87.0
# 4           80.0             91             64             90.0
# 5           75.0             92             60             97.0
# 6           79.0             89             67             76.0
# 7           72.0             89             65             94.0
# 8           75.0             78             79             84.0
# 10          69.0             76             68             77.0
# 11          76.0             89             67             75.0
# 12          68.0             81             76             75.0
# 13          63.0             76             97             93.0
# 14          66.0             94             68             80.0
# ...

# %%
ndf=df
ndf.fillna(0)
# Out:
#     marths score  reading score  writing score  placement score  \
# 0           61.0             83             80             75.0
# 1           60.0             86             61             79.0
# 2           63.0             94             69             79.0
# 3           74.0             32             80             87.0
# 4           80.0             91             64             90.0
# 5           75.0             92             60             97.0
# 6           79.0             89             67             76.0
# 7           72.0             89             65             94.0
# 8           75.0             78             79             84.0
# 9            0.0             85             72             82.0
# 10          69.0             76             68             77.0
# 11          76.0             89             67             75.0
# 12          68.0             81             76             75.0
# 13          63.0             76             97             93.0
# ...

# %%
df.notnull()
# Out:
#     marths score  reading score  writing score  placement score  \
# 0           True           True           True             True
# 1           True           True           True             True
# 2           True           True           True             True
# 3           True           True           True             True
# 4           True           True           True             True
# 5           True           True           True             True
# 6           True           True           True             True
# 7           True           True           True             True
# 8           True           True           True             True
# 9          False           True           True             True
# 10          True           True           True             True
# 11          True           True           True             True
# 12          True           True           True             True
# 13          True           True           True             True
# ...

# %%
m_v=df['marths score'].mean()
df['marths score'].fillna(value=m_v, inplace=True)
df
# Out:
# C:\Users\diksh\AppData\Local\Temp\ipykernel_14804\3298528543.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['marths score'].fillna(value=m_v, inplace=True)
#     marths score  reading score  writing score  placement score  \
# 0      61.000000             83             80             75.0
# 1      60.000000             86             61             79.0
# 2      63.000000             94             69             79.0
# 3      74.000000             32             80             87.0
# ...

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     marths score  reading score  writing score  placement score  \
# 0      61.000000             83             80             75.0
# 1      60.000000             86             61             79.0
# 2      63.000000             94             69             79.0
# 3      74.000000             32             80             87.0
# 4      80.000000             91             64             90.0
# 5      75.000000             92             60             97.0
# 6      79.000000             89             67             76.0
# 7      72.000000             89             65             94.0
# 8      75.000000             78             79             84.0
# 9      70.666667             85             72             82.0
# 10     69.000000             76             68             77.0
# 11     76.000000             89             67             75.0
# 12     68.000000             81             76             75.0
# 13     63.000000             76             97             93.0
# ...

# %%
ndf.dropna()
# Out:
#     marths score  reading score  writing score  placement score  \
# 0      61.000000             83             80             75.0
# 1      60.000000             86             61             79.0
# 2      63.000000             94             69             79.0
# 3      74.000000             32             80             87.0
# 4      80.000000             91             64             90.0
# 5      75.000000             92             60             97.0
# 6      79.000000             89             67             76.0
# 7      72.000000             89             65             94.0
# 9      70.666667             85             72             82.0
# 10     69.000000             76             68             77.0
# 11     76.000000             89             67             75.0
# 12     68.000000             81             76             75.0
# 13     63.000000             76             97             93.0
# 14     66.000000             94             68             80.0
# ...

# %%
ndf.dropna(how='all')
# Out:
#     marths score  reading score  writing score  placement score  \
# 0      61.000000             83             80             75.0
# 1      60.000000             86             61             79.0
# 2      63.000000             94             69             79.0
# 3      74.000000             32             80             87.0
# 4      80.000000             91             64             90.0
# 5      75.000000             92             60             97.0
# 6      79.000000             89             67             76.0
# 7      72.000000             89             65             94.0
# 8      75.000000             78             79             84.0
# 9      70.666667             85             72             82.0
# 10     69.000000             76             68             77.0
# 11     76.000000             89             67             75.0
# 12     68.000000             81             76             75.0
# 13     63.000000             76             97             93.0
# ...
